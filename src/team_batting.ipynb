# %%
import pandas as pd
import numpy as np


df = pd.read_csv("team_batting.csv")
test = pd.DataFrame(df.iloc[:, 2:])
print(test)
# Out:
#                     Name  Age  Games   PA   AB  Runs  Hits  2B  3B  HR  ...  \
# 0          Yadier Molina   38    121  473  440    45   111  19   0  11  ...
# 1       Paul Goldschmidt   33    158  679  603   102   177  36   2  31  ...
# 2            Tommy Edman   26    159  691  641    91   168  41   3  11  ...
# 3            Paul DeJong   27    113  402  356    44    70  10   1  19  ...
# 4          Nolan Arenado   30    157  653  593    81   151  34   3  34  ...
# 5          Tyler O'Neill   26    138  537  482    89   138  26   2  34  ...
# 6         Harrison Bader   27    103  401  367    45    98  21   1  16  ...
# 7          Dylan Carlson   22    149  619  542    79   144  31   4  18  ...
# 8           Edmundo Sosa   25    113  326  288    39    78   8   4   6  ...
# 9         Matt Carpenter   35    130  249  207    18    35  11   1   3  ...
# 10        Andrew Knizner   26     63  185  161    18    28   7   0   1  ...
# ...
